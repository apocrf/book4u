# %%
import pandas as pd

# %%
a = pd.read_parquet("../data/interim/GoodReads_books_clean.parquet")
a
# Out:
#                                  author
# 0                  Laurence M. Hauptman  \
# 1      Charlotte Fiell,Emmanuelle Dirix
# 2                         Andy Anderson
# 3                  Carlotta R. Anderson
# 4                       Jeffrey Pfeffer
# ...                                 ...
# 48721                      Philip Hoare
# 48722                        Sarah Lean
# 48723                    C. John Miller
# 48724                     Albert Marrin
# 48725                     Marc E. Fitch
#
#                                                     desc
# 0      Reveals that several hundred thousand Indians ...  \
# 1      Fashion Sourcebook - 1920s is the first book i...
# 2      The seminal history and analysis of the Hungar...
# 3      "All-American Anarchist" chronicles the life a...
# 4      "Competitive Advantage Through People" explore...
# ...                                                  ...
# 48721  A startling new book, his most personal to dat...
# ...

# %%
id_mapping_data = a[["author", "title", "desc"]]
id_mapping_data
# Out:
#                                  author
# 0                  Laurence M. Hauptman  \
# 1      Charlotte Fiell,Emmanuelle Dirix
# 2                         Andy Anderson
# 3                  Carlotta R. Anderson
# 4                       Jeffrey Pfeffer
# ...                                 ...
# 48721                      Philip Hoare
# 48722                        Sarah Lean
# 48723                    C. John Miller
# 48724                     Albert Marrin
# 48725                     Marc E. Fitch
#
#                                                    title
# 0      Between Two Fires: American Indians in the Civ...  \
# 1                               Fashion Sourcebook 1920s
# 2                                             Hungary 56
# 3      All-American Anarchist: Joseph A. Labadie and ...
# 4      Competitive Advantage Through People: Unleashi...
# ...                                                  ...
# 48721                                     The Sea Inside
# ...

# %%
id_mapping_data.to_parquet("./data/interim/full_id_mapping.parquet")

# %%
id_title_mapping_data = a[["title"]]
id_title_mapping_data
# Out:
#                                                    title
# 0      Between Two Fires: American Indians in the Civ...
# 1                               Fashion Sourcebook 1920s
# 2                                             Hungary 56
# 3      All-American Anarchist: Joseph A. Labadie and ...
# 4      Competitive Advantage Through People: Unleashi...
# ...                                                  ...
# 48721                                     The Sea Inside
# 48722                                  A Horse for Angel
# 48723  A Faith Worth Sharing: A Lifetime of Conversat...
# 48724  A Volcano Beneath the Snow: John Brown's War A...
# 48725  Paranormal Nation: Why America Needs Ghosts, U...
#
# [48726 rows x 1 columns]

# %%
id_title_mapping_data.to_parquet("../data/interim/id_title_mapping_data.parquet")
